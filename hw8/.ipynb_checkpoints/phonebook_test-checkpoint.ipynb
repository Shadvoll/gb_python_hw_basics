# %%
import task38
phonebook = task38.Phonebook("phonebook.csv")
phonebook.work_with_phonebook()
# Out:
# Выберите необходимое действие:
# 1. Отобразить весь справочник
# 2. Найти абонента по фамилии
# 3. Найти абонента по номеру телефона
# 4. Добавить абонента в справочник
# 5. Изменить запись по id
# 6. Удалить запись по id
# 7. Сохранить справочник в текстовом формате
# 8. Закончить работу
# 1
#
# ID: 1
# Фамилия: Иванов
# Имя: Иван
# Телефон: 111
# Описание: описание Иванова
#
#
# ID: 2
# Фамилия: Петров
# Имя: Петр
# Телефон: 222
# Описание: описание Петрова
#
#
# ID: 3
# Фамилия: Васичкина
# Имя: Василиса
# Телефон: 333
# Описание: описание Васичкиной
#
#
# ID: 4
# Фамилия: Питонов
# Имя: Антон
# Телефон: 777
# Описание: умеет в Питон
#
#
# ID: 5
# Фамилия: 555
# Имя: 333
# Телефон: 789
# Описание: dfdf
#
#
# ID: 6
# Фамилия: test
# Имя: test
# Телефон: test
# Описание: test
#
#
# ID: 7
# Фамилия: test2
# Имя: test2
# Телефон: test2
# Описание: test2
#
#
#
# Выберите необходимое действие:
# 1. Отобразить весь справочник
# 2. Найти абонента по фамилии
# ...
